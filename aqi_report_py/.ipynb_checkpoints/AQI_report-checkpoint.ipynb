# %% [markdown]
# # A Jupyter Notebook to poll the daily AQI readings for a location.

# %% [markdown]
# Build the API query URL

# %%
base_url = "https://www.airnowapi.org/aq/data/"

# %%
from datetime import datetime
from datetime import timedelta

# %%
timespan = 24 #hours
now = datetime.now()
then = now - timedelta(hours=timespan)

# %%
endDate = now.strftime("%Y-%m-%dT%H")
startDate = then.strftime("%Y-%m-%dT%H")

# %%
#Constant endpoints
parameters = "parameters=OZONE,PM25,PM10,CO,NO2,SO2"
boundingBox = "BBOX=-123.146648,46.996876,-121.487713,48.204308"
dataType = "dataType=B"
format_ = "format=text/csv"
verbose = "verbose=1"
nowcastonly = "nowcastonly=1"
includeRaw = "includerawconcentrations=1"

# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
query_url = base_url + "?" + "startDate=" + startDate + "&" + "endDate=" + endDate + "&" + parameters + "&" + boundingBox + "&" + dataType + "&" + format_ + "&" + verbose + "&" + nowcastonly + "&" + includeRaw + "&API_KEY=" + os.getenv("AIRNOW_API_KEY")

# %%
import requests

# %%
response = requests.get(query_url)
response = response.content

# %%
import pandas as pd
import io

# %%
colnames = ["Latitude", "Longitude", "UTC", "Pollutant", "Concentration", "Unit", "Raw_Concentration", "AQI", "Category", "Site_Name", "Site_Agency", "AQS_ID", "Full_AWS_ID"]

# %%
df = pd.read_csv(io.StringIO(response.decode('utf-8')), names = colnames)

# %%
df
# Out:
#       Latitude   Longitude               UTC Pollutant  Concentration   Unit  \
# 0    47.213551 -123.100807  2022-12-21T22:00     PM2.5            2.7  UG/M3
# 1    47.029301 -122.821503  2022-12-21T22:00     OZONE           27.0    PPB
# 2    47.029301 -122.821503  2022-12-21T22:00     PM2.5            1.7  UG/M3
# 3    48.129101 -122.778900  2022-12-21T22:00     PM2.5            3.5  UG/M3
# 4    47.592675 -122.627397  2022-12-21T22:00     PM2.5            5.0  UG/M3
# ..         ...         ...               ...       ...            ...    ...
# 656  47.386101 -122.230202  2022-12-22T22:00     PM2.5            3.3  UG/M3
# 657  47.281400 -122.223300  2022-12-22T22:00     PM2.5            3.2  UG/M3
# 658  48.054315 -122.171529  2022-12-22T22:00     PM2.5            8.3  UG/M3
# 659  47.600863 -122.148397  2022-12-22T22:00     PM2.5            1.4  UG/M3
# 660  47.490200 -121.772697  2022-12-22T22:00     PM2.5            1.2  UG/M3
#
#      Raw_Concentration  AQI  Category                       Site_Name  \
# 0                  3.2   11         1              Shelton-W Franklin
# 1                 29.0   25         1                Lacey-College St
# 2                  1.7    7         1                Lacey-College St
# 3                  3.7   15         1          Port Townsend-San Juan
# 4                  6.0   21         1            Bremerton-Spruce Ave
# ..                 ...  ...       ...                             ...
#      Raw_Concentration  AQI  Category           Site_Name  \
# 104               36.0   75         2  Marysville-7th Ave
# 131               19.0   70         2  Marysville-7th Ave
# 158               23.0   72         2  Marysville-7th Ave
# 185               17.0   67         2  Marysville-7th Ave
# 212               33.0   81         2  Marysville-7th Ave
# 239               27.0   81         2  Marysville-7th Ave
# 266               35.0   90         2  Marysville-7th Ave
# 293               25.0   84         2  Marysville-7th Ave
# 320               14.0   70         2  Marysville-7th Ave
# 346               14.0   62         2  Marysville-7th Ave
# 371               14.0   59         2  Marysville-7th Ave
# 398               11.0   54         2  Marysville-7th Ave
# 425               15.0   55         2  Marysville-7th Ave
# 452               11.0   52         2  Marysville-7th Ave
# 479               20.0   60         2  Marysville-7th Ave
# 506               20.0   64         2  Marysville-7th Ave
# 533               22.0   68         2  Marysville-7th Ave
# 560               21.0   69         2  Marysville-7th Ave
# 587               16.0   64         2  Marysville-7th Ave
#
#                           Site_Agency     AQS_ID   Full_AWS_ID
# 104  Washington Department of Ecology  530611007  840530611007
# 131  Washington Department of Ecology  530611007  840530611007
# 158  Washington Department of Ecology  530611007  840530611007
# 185  Washington Department of Ecology  530611007  840530611007
# 212  Washington Department of Ecology  530611007  840530611007
# 239  Washington Department of Ecology  530611007  840530611007
# 266  Washington Department of Ecology  530611007  840530611007
# 293  Washington Department of Ecology  530611007  840530611007
# 320  Washington Department of Ecology  530611007  840530611007
# 346  Washington Department of Ecology  530611007  840530611007
# 371  Washington Department of Ecology  530611007  840530611007
# 398  Washington Department of Ecology  530611007  840530611007
# 425  Washington Department of Ecology  530611007  840530611007
# 452  Washington Department of Ecology  530611007  840530611007
# 479  Washington Department of Ecology  530611007  840530611007
# 506  Washington Department of Ecology  530611007  840530611007
# 533  Washington Department of Ecology  530611007  840530611007
# 560  Washington Department of Ecology  530611007  840530611007
# 587  Washington Department of Ecology  530611007  840530611007

# %%
if len(exceeding_df) > 0 :
    print("AQI threshold exceeded for", len(exceeding_df), "station(s)")
else:
    print("All readings okay")
# Out:
# AQI threshold exceeded for 19 station(s)

# %%
import pins
board = pins.board_rsconnect()
board.pin_write(exceeding_df, "katie.masiello/aqi_exceeding_stations", type="csv")
# Out:
# Writing pin:
# Name: 'katie.masiello/aqi_exceeding_stations'
# Version: 20221222T230033Z-9fae2
# Meta(title='aqi_exceeding_stations: a pinned 661 x 13 DataFrame', description=None, created='20221222T230033Z', pin_hash='9fae21cbcb0636a1', file='aqi_exceeding_stations.csv', file_size=91867, type='csv', api_version=1, version=VersionRaw(version='67504'), tags=None, name='katie.masiello/aqi_exceeding_stations', user={}, local={})
